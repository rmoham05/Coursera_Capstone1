# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: //anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %% [markdown]
# # Collecting school locations from

# %%
CLIENT_ID = 'ZOZMZY5XMFZ0SAN2VYJ4HCYZOQ521DZ3JKDF11CHJAQNHXOQ' # your Foursquare ID
CLIENT_SECRET = 'MFVOK4VBBZXMUEITLJ5PGW53ERCNXYT1C4L1TT4XPPKBEAAJ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZOZMZY5XMFZ0SAN2VYJ4HCYZOQ521DZ3JKDF11CHJAQNHXOQ
# CLIENT_SECRET:MFVOK4VBBZXMUEITLJ5PGW53ERCNXYT1C4L1TT4XPPKBEAAJ

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %%
search_query = 'school'
radius = 500
print(search_query + ' .... OK!')
# Out:
# school .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ecd8fa50be7b4001b24791f'},
#  'response': {'venues': [{'id': '4ada0d95f964a520d41d21e3',
#     'name': 'Ted Rogers School of Management',
#     'location': {'address': '575 Bay St.',
#      'crossStreet': 'at Dundas St. W',
#      'lat': 43.65564568498175,
#      'lng': -79.38273654779792,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564568498175,
#        'lng': -79.38273654779792}],
#      'distance': 259,
#      'postalCode': 'M5G 2C5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['575 Bay St. (at Dundas St. W)',
#       'Toronto ON M5G 2C5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 2  [{'id': '4bf58dd8d48988d162941735', 'name': 'O...    False
# 3  [{'id': '4bf58dd8d48988d137941735', 'name': 'T...    False
# 4  [{'id': '4bf58dd8d48988d1b2941735', 'name': 'C...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ada0d95f964a520d41d21e3          575 Bay St.          CA       Toronto
# 1  502ba134e4b057455a9a1284  439 University Ave.          CA       Toronto
# 2  4eb837f477c897273837381e               Dundas          CA       Toronto
# 3  58a5e6415cab2f5be9876d5f     345 Yonge Street          CA       Toronto
# 4  4f24726ce4b06176445b9c4e                  NaN          CA       Toronto
#
#   location.country                location.crossStreet  location.distance  \
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                     Ted Rogers School of Management
# 1           Ontario Public School Boards' Association
# 2               Ted Rogers School of Management Patio
# 3      Ryerson School of Performance (Studio Theatre)
# 4                         South East Polk High School
# 5                         The IELTS School of Toronto
# 6              Ted Rogers School of Retail Management
# 7   Ryerson School of Performance (Atrium on Bay O...
# 8                                 Toronto Film School
# 9                                 Toronto Film School
# 10                        Canadian Online High School
# 11                         Contact Alternative School
# 12   Yeates School Of Graduate Studies Administration
# 13  North York St. Timothy YMCA Before and After S...
# 14                Maryvale High School Cheektowaga Ny
# 15                           St Michaels Choir School
# ...

# %%
dataframe_filtered.name
# Out:
# 0                       Ted Rogers School of Management
# 1             Ontario Public School Boards' Association
# 2                 Ted Rogers School of Management Patio
# 3        Ryerson School of Performance (Studio Theatre)
# 4                           South East Polk High School
# 5                           The IELTS School of Toronto
# 6                Ted Rogers School of Retail Management
# 7     Ryerson School of Performance (Atrium on Bay O...
# 8                                   Toronto Film School
# 9                                   Toronto Film School
# 10                          Canadian Online High School
# 11                           Contact Alternative School
# 12     Yeates School Of Graduate Studies Administration
# 13    North York St. Timothy YMCA Before and After S...
# 14                  Maryvale High School Cheektowaga Ny
# 15                             St Michaels Choir School
# 16                                            Starbucks
# ...

# %% [markdown]
# # Pedestrian accident Dataset

# %% [markdown]
# **The Dataset can be found in** http://data.torontopolice.on.ca/datasets/pedestrians

# %%
df = pd.read_csv('Pedestrians.csv',encoding='latin1')
print('Data loaded')
# Out:
# Data loaded

# %%
df.head()
# Out:
#      Index_      ACCNUM  YEAR           DATE  TIME  Hour      STREET1  \
# 0   7817616     1355791  2013  1368331200000   139     1   QUEEN ST E
# 1   7817617     1355791  2013  1368331200000   139     1   QUEEN ST E
# 2   7817618     1355791  2013  1368331200000   139     1   QUEEN ST E
# 3  80929712  8000172626  2018  1517115600000   140     1  BATHURST ST
# 4  80929713  8000172626  2018  1517115600000   140     1  BATHURST ST
#
#          STREET2 OFFSET      ROAD_CLASS  ... EMERG_VEH  PASSENGER  SPEEDING  \
# 0    EASTERN AVE         Major Arterial  ...
# 1    EASTERN AVE         Major Arterial  ...
# 2    EASTERN AVE         Major Arterial  ...
# 3  RIDGE HILL DR         Major Arterial  ...
# 4  RIDGE HILL DR         Major Arterial  ...
#
#    AG_DRIV  REDLIGHT  ALCOHOL  DISABILITY  Hood_ID               Neighbourh  \
# 0                                               63         The Beaches (63)
# 1                                               63         The Beaches (63)
# ...
