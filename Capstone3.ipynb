# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /anaconda3/lib/python3.7/site-packages (1.38.1)
# Requirement already satisfied: click in /anaconda3/lib/python3.7/site-packages (from geocoder) (7.0)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: ratelim in /anaconda3/lib/python3.7/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: future in /anaconda3/lib/python3.7/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: decorator in /anaconda3/lib/python3.7/site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->geocoder) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->geocoder) (2019.6.16)

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 2.3MB/s ta 0:00:01
# Requirement already satisfied: jinja2>=2.9 in /anaconda3/lib/python3.7/site-packages (from folium) (2.10.1)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/13/fb/9eacc24ba3216510c6b59a4ea1cd53d87f25ba76237d7f4393abeaf4c94e/branca-0.4.1-py3-none-any.whl
# Requirement already satisfied: numpy in /anaconda3/lib/python3.7/site-packages (from folium) (1.16.4)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2.8)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import geocoder # import geocoder
import requests 
from bs4 import BeautifulSoup 

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
URL = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
table = soup.find('div', attrs = {'id':'container'}) 

# print(soup.prettify()) 
print('Page Scrapped.')
# Out:
# Page Scrapped.

# %%
postalCodes = [];
boroughs= [];
neighborhoods = [];
columnNum = 1;
passVal = False

for row in soup.find_all('td'):
    for cell in row:
        if cell.string and cell.string[0].isalpha() and len(cell.string) > 2:
            passVal = False
            if columnNum == 1:
                if passVal == False and cell.string[1].isdigit():
                    postalCodes.append(cell.string);   
                    columnNum = 2
                else:
                    continue
            elif columnNum == 2 :
                if cell.string == 'Not assigned':
                    passVal = True
                    del postalCodes[-1]
                    columnNum = 1
                    continue
                else:
                    boroughs.append(cell.string);      
                    columnNum = 3
            elif columnNum == 3 :
                if cell.string == 'Not assigned\n':
                    neighborhoods.append(boroughs[-1])
                else:
                    neighborhoods.append(cell.string); 
                columnNum = 1
                
print('Data Collected.')
# Out:
# Data Collected.

# %%
# define the dataframe columns
column_names = ['PostalCode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighbors = pd.DataFrame(columns=column_names)

neighbors
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
# initialize your variable to None
lat_lng_coords = None

for data in range(0, len(postalCodes)-1):
    code = postalCodes[data]
    borough = boroughs[data]
    neighborhood_name = neighborhoods[data]
    
    g = geocoder.arcgis('{}, Toronto, Ontario'.format(code))
    lat_lng_coords = g.latlng

    neighbors = neighbors.append({ 'PostalCode': code,
                                   'Borough': borough,
                                   'Neighborhood': neighborhood_name,
                                   'Latitude': lat_lng_coords[0],
                                   'Longitude': lat_lng_coords[1]}, ignore_index=True)
    
neighbors
# Out:
#     PostalCode            Borough  \
# 0         M1A
#       Not assigned
#
# 1         M3A
#         North York
#
# 2         M4A
#         North York
#
# 3         M5A
#   Downtown Toronto
#
# 4         M6A
#         North York
#
# 5         M7A
#   Downtown Toronto
#
# 6         M8A
#       Not assigned
#
# 7         M1B
#        Scarborough
#
# 8         M2B
#       Not assigned
#
# 9         M4B
#          East York
#
# 10        M5B
#   Downtown Toronto
#
# 11        M6B
#         North York
#
# 12        M7B
#       Not assigned
#
# 13        M9B
#          Etobicoke
#
# 14        M1C
#        Scarborough
#
# 15        M2C
#       Not assigned
#
# 16        M4C
#          East York
#
# 17        M5C
#   Downtown Toronto
#
# 18        M6C
#               York
#
# 19        M7C
#       Not assigned
#
# 20        M9C
#          Etobicoke
#
# 21        M1E
#        Scarborough
#
# 22        M2E
#       Not assigned
#
# 23        M4E
#       East Toronto
#
# 24        M5E
#   Downtown Toronto
#
# 25        M6E
#               York
#
# 26        M7E
#       Not assigned
#
# 27        M9E
#       Not assigned
#
# 28        M2G
#       Not assigned
#
# 29        M4G
#          East York
#
# 30        M5G
#   Downtown Toronto
#
# 31        M6G
#   Downtown Toronto
#
# 32        M7G
#       Not assigned
#
# 33        M9G
#       Not assigned
#
# 34        M2H
#         North York
#
# 35        M3H
#         North York
#
# 36        M4H
#          East York
#
# 37        M5H
#   Downtown Toronto
#
# 38        M6H
#       West Toronto
#
# 39        M7H
#       Not assigned
#
# 40        M9H
#       Not assigned
#
# 41        M2J
#         North York
#
# 42        M3J
#         North York
#
# 43        M4J
#          East York
#
# 44        M5J
#   Downtown Toronto
#
# 45        M6J
#       West Toronto
#
# 46        M7J
#       Not assigned
#
# 47        M9J
#       Not assigned
#
# 48        M2K
#         North York
#
# 49        M3K
#         North York
#
# 50        M4K
#       East Toronto
#
# 51        M5K
#   Downtown Toronto
#
# 52        M6K
#       West Toronto
#
# 53        M7K
#       Not assigned
#
# 54        M9K
#       Not assigned
#
# 55        M2L
#         North York
#
# 56        M3L
#         North York
#
# 57        M4L
#       East Toronto
#
# 58        M5L
#   Downtown Toronto
#
# 59        M6L
#         North York
#
# 60        M7L
#       Not assigned
#
# 61        M9L
#         North York
#
# 62        M1M
#        Scarborough
#
# 63        M2M
#         North York
#
# 64        M3M
#         North York
#
# 65        M4M
#       East Toronto
#
# 66        M5M
#         North York
#
# 67        M6M
#               York
#
# 68        M7M
#       Not assigned
#
# 69        M9M
#         North York
#
# 70        M1N
#        Scarborough
#
# 71        M2N
#         North York
#
# 72        M3N
#         North York
#
# 73        M4N
#    Central Toronto
#
# 74        M5N
#    Central Toronto
#
# 75        M6N
#               York
#
# 76        M7N
#       Not assigned
#
# 77        M9N
#               York
#
# 78        M1P
#        Scarborough
#
# 79        M2P
#         North York
#
# 80        M3P
#       Not assigned
#
# 81        M5P
#    Central Toronto
#
# 82        M6P
#       West Toronto
#
# 83        M7P
#       Not assigned
#
# 84        M9P
#          Etobicoke
#
# 85        M1R
#        Scarborough
#
# 86        M2R
#         North York
#
# 87        M3R
#       Not assigned
#
# 88        M5R
#    Central Toronto
#
# 89        M6R
#       West Toronto
#
# 90        M7R
#        Mississauga
#
# 91        M8R
#       Not assigned
#
# 92        M1S
#        Scarborough
#
# 93        M2S
#       Not assigned
#
# 94        M4S
#    Central Toronto
#
# 95        M5S
#   Downtown Toronto
#
# 96        M6S
#       West Toronto
#
# 97        M7S
#       Not assigned
#
# 98        M9S
#       Not assigned
#
# 99        M2T
#       Not assigned
#
# 100       M4T
#    Central Toronto
#
# 101       M5T
#   Downtown Toronto
#
# 102       M6T
#       Not assigned
#
# 103       M8T
#       Not assigned
#
# 104       M1V
#        Scarborough
#
# 105       M2V
#       Not assigned
#
# 106       M4V
#    Central Toronto
#
# 107       M5V
#   Downtown Toronto
#
# 108       M6V
#       Not assigned
#
# 109       M8V
#          Etobicoke
#
# 110       M9V
#          Etobicoke
#
# 111       M1W
#        Scarborough
#
# 112       M2W
#       Not assigned
#
# 113       M4W
#   Downtown Toronto
#
# 114       M5W
#   Downtown Toronto
#
# 115       M6W
#       Not assigned
#
# 116       M8W
#          Etobicoke
#
# 117       M9W
#          Etobicoke
#
# 118       M1X
#        Scarborough
#
# 119       M2X
#       Not assigned
#
# 120       M4X
#   Downtown Toronto
#
# 121       M5X
#   Downtown Toronto
#
# 122       M6X
#       Not assigned
#
# 123       M8X
#          Etobicoke
#
# 124       M9X
#       Not assigned
#
# 125       M2Y
#       Not assigned
#
# 126       M4Y
#   Downtown Toronto
#
# 127       M5Y
#       Not assigned
#
# 128       M7Y
#       East Toronto
#
# 129       M8Y
#          Etobicoke
#
# 130       M9Y
#       Not assigned
#
# 131       M2Z
#       Not assigned
#
# 132       M4Z
#       Not assigned
#
# 133       M6Z
#       Not assigned
#
# 134       M8Z
#          Etobicoke
#
#
#                                           Neighborhood   Latitude  Longitude
# 0                                                 M2A
#   43.648690 -79.385440
# 1                                           Parkwoods
#   43.752935 -79.335641
# 2                                    Victoria Village
#   43.728102 -79.311890
# 3                           Regent Park, Harbourfront
#   43.650964 -79.353041
# 4                    Lawrence Manor, Lawrence Heights
#   43.723265 -79.451211
# 5         Queen's Park, Ontario Provincial Government
#   43.661790 -79.389390
# 6                                                 M9A
#   43.648690 -79.385440
# 7                                      Malvern, Rouge
#   43.808626 -79.189913
# 8                                                 M3B
#   43.648690 -79.385440
# 9                     Parkview Hill, Woodbine Gardens
#   43.707193 -79.311529
# 10                           Garden District, Ryerson
#   43.657491 -79.377529
# 11                                          Glencairn
#   43.707279 -79.447500
# 12                                                M8B
#   43.648690 -79.385440
# 13   West Deane Park, Princess Gardens, Martin Grov...  43.650023 -79.554089
# 14             Rouge Hill, Port Union, Highland Creek
#   43.785779 -79.157368
# 15                                                M3C
#   43.648690 -79.385440
# 16                                   Woodbine Heights
#   43.689740 -79.308507
# 17                                     St. James Town
#   43.651734 -79.375554
# 18                                 Humewood-Cedarvale
#   43.691730 -79.430013
# 19                                                M8C
#   43.648690 -79.385440
# 20   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.637813 -79.576484
# 21                  Guildwood, Morningside, West Hill
#   43.765806 -79.185284
# 22                                                M3E
#   43.648690 -79.385440
# 23                                        The Beaches
#   43.678148 -79.295349
# 24                                        Berczy Park
#   43.645196 -79.373855
# 25                                Caledonia-Fairbanks
#   43.689118 -79.450650
# 26                                                M8E
#   43.648690 -79.385440
# 27                                                M1G
#   43.648690 -79.385440
# 28                                                M3G
#   43.648690 -79.385440
# 29                                            Leaside
#   43.709414 -79.363100
# 30                                 Central Bay Street
#   43.656072 -79.385653
# 31                                           Christie
#   43.668602 -79.420387
# 32                                                M8G
#   43.648690 -79.385440
# 33                                                M1H
#   43.648690 -79.385440
# 34                                  Hillcrest Village
#   43.802556 -79.356566
# 35    Bathurst Manor, Wilson Heights, Downsview North
#   43.757394 -79.442394
# 36                                   Thorncliffe Park
#   43.702072 -79.351614
# 37                           Richmond, Adelaide, King
#   43.650542 -79.384116
# 38                       Dufferin, Dovercourt Village
#   43.664910 -79.438664
# 39                                                M8H
#   43.648690 -79.385440
# 40                                                M1J
#   43.648690 -79.385440
# 41                       Fairview, Henry Farm, Oriole
#   43.780306 -79.348687
# 42                    Northwood Park, York University
#   43.764872 -79.492497
# 43      East Toronto, Broadview North (Old East York)
#   43.687046 -79.333890
# 44   Harbourfront East, Union Station, Toronto Isla...  43.623750 -79.369200
# 45                           Little Portugal, Trinity
#   43.648636 -79.417752
# 46                                                M8J
#   43.648690 -79.385440
# 47                                                M1K
#   43.648690 -79.385440
# 48                                    Bayview Village
#   43.780607 -79.376921
# 49                                          Downsview
#   43.739101 -79.467631
# 50                       The Danforth West, Riverdale
#   43.683424 -79.354564
# 51           Toronto Dominion Centre, Design Exchange
#   43.646923 -79.381626
# 52       Brockton, Parkdale Village, Exhibition Place
#   43.639922 -79.431240
# 53                                                M8K
#   43.648690 -79.385440
# 54                                                M1L
#   43.648690 -79.385440
# 55                           York Mills, Silver Hills
#   43.749360 -79.380690
# 56                                          Downsview
#   43.729992 -79.512027
# 57                     India Bazaar, The Beaches West
#   43.668291 -79.315578
# 58                     Commerce Court, Victoria Hotel
#   43.648283 -79.378750
# 59           North Park, Maple Leaf Park, Upwood Park
#   43.713530 -79.488724
# 60                                                M8L
#   43.648690 -79.385440
# 61                                      Humber Summit
#   43.759381 -79.557174
# 62    Cliffside, Cliffcrest, Scarborough Village West
#   43.723538 -79.228353
# 63                            Willowdale, Newtonbrook
#   43.791800 -79.406428
# 64                                          Downsview
#   43.733220 -79.497700
# 65                                    Studio District
#   43.648000 -79.339260
# 66                  Bedford Park, Lawrence Manor East
#   43.735447 -79.417944
# 67   Del Ray, Mount Dennis, Keelsdale and Silverthorn
#   43.695075 -79.487179
# 68                                                M8M
#   43.648690 -79.385440
# 69                                   Humberlea, Emery
#   43.733682 -79.544381
# 70                        Birch Cliff, Cliffside West
#   43.696448 -79.265642
# 71                        Willowdale, Willowdale East
#   43.769077 -79.413695
# 72                                          Downsview
#   43.755819 -79.519973
# 73                                      Lawrence Park
#   43.729455 -79.386415
# 74                                           Roselawn
#   43.710634 -79.418748
# 75                      Runnymede, The Junction North
#   43.676856 -79.478691
# 76                                                M8N
#   43.648690 -79.385440
# 77                                             Weston
#   43.705496 -79.520370
# 78   Dorset Park, Wexford Heights, Scarborough Town...  43.761310 -79.269940
# 79                                    York Mills West
#   43.750260 -79.398355
# 80                                                M4P
#   43.648690 -79.385440
# 81    Forest Hill North & West, Forest Hill Road Park
#   43.694460 -79.410280
# 82                      High Park, The Junction South
#   43.658720 -79.463150
# 83                                                M8P
#   43.648690 -79.385440
# 84                                          Westmount
#   43.696296 -79.533126
# 85                                  Wexford, Maryvale
#   43.750043 -79.300537
# 86                        Willowdale, Willowdale West
#   43.779912 -79.445229
# 87                                                M4R
#   43.648690 -79.385440
# 88                The Annex, North Midtown, Yorkville
#   43.674911 -79.403940
# 89                             Parkdale, Roncesvalles
#   43.647840 -79.448388
# 90              Canada Post Gateway Processing Centre
#   43.648690 -79.385440
# 91                                                M9R
#   43.648690 -79.385440
# 92                                          Agincourt
#   43.793930 -79.265694
# 93                                                M3S
#   43.648690 -79.385440
# 94                                         Davisville
#   43.703327 -79.385649
# 95                     University of Toronto, Harbord
#   43.663281 -79.398088
# 96                                 Runnymede, Swansea
#   43.649725 -79.482692
# 97                                                M8S
#   43.648690 -79.385440
# 98                                                M1T
#   43.648690 -79.385440
# 99                                                M3T
#   43.648690 -79.385440
# 100                       Moore Park, Summerhill East
#   43.690328 -79.383522
# 101         Kensington Market, Chinatown, Grange Park
#   43.653497 -79.397410
# 102                                               M7T
#   43.648690 -79.385440
# 103                                               M9T
#   43.648690 -79.385440
# 104  Milliken, Agincourt North, Steeles East, L'Amo...  43.817998 -79.280887
# 105                                               M3V
#   43.648690 -79.385440
# 106  Summerhill West, Rathnelly, South Hill, Forest...  43.686378 -79.402372
# 107  CN Tower, King and Spadina, Railway Lands, Har...  43.640539 -79.397435
# 108                                               M7V
#   43.648690 -79.385440
# 109      New Toronto, Mimico South, Humber Bay Shores
#   43.610075 -79.499751
# 110  South Steeles, Silverstone, Humbergate, Jamest...  43.744055 -79.581203
# 111                     Steeles West, L'Amoreaux West
#   43.800530 -79.321830
# 112                                               M3W
#   43.648690 -79.385440
# 113                                          Rosedale
#   43.681893 -79.376706
# 114                                    Stn A PO Boxes
#   43.648700 -79.385450
# 115                                               M7W
#   43.648690 -79.385440
# 116                            Alderwood, Long Branch
#   43.600895 -79.540387
# 117               Northwest, West Humber - Clairville
#   43.711615 -79.588351
# 118                                       Upper Rouge
#   43.834768 -79.204101
# 119                                               M3X
#   43.648690 -79.385440
# 120                       St. James Town, Cabbagetown
#   43.667656 -79.367326
# 121            First Canadian Place, Underground city
#   43.648269 -79.381884
# 122                                               M7X
#   43.648690 -79.385440
# 123     The Kingsway, Montgomery Road, Old Mill North
#   43.653340 -79.509766
# 124                                               M1Y
#   43.648690 -79.385440
# 125                                               M3Y
#   43.648690 -79.385440
# 126                              Church and Wellesley
#   43.666659 -79.381472
# 127                                               M6Y
#   43.648690 -79.385440
# 128  Business reply mail Processing Centre, South C...  43.648700 -79.385450
# 129  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.632798 -79.493017
# 130                                               M1Z
#   43.648690 -79.385440
# 131                                               M3Z
#   43.648690 -79.385440
# 132                                               M5Z
#   43.648690 -79.385440
# 133                                               M7Z
#   43.648690 -79.385440
# 134  Mimico NW, The Queensway West, South of Bloor,...  43.625490 -79.526000

# %%
neighborhood_name = neighbors.loc[0, 'Neighborhood'] # neighborhood name
latitude = neighbors.loc[0, 'Latitude'] # neighborhood latitude value
longitude = neighbors.loc[0, 'Longitude'] # neighborhood longitude value

 
CLIENT_ID = 'ZOZMZY5XMFZ0SAN2VYJ4HCYZOQ521DZ3JKDF11CHJAQNHXOQ' 
CLIENT_SECRET = 'MFVOK4VBBZXMUEITLJ5PGW53ERCNXYT1C4L1TT4XPPKBEAAJ' 
VERSION = '20180604'
LIMIT = 30
search_query = 'Italian'                                                               

radius = 500 # define radius



url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ecd16af0a2972001b1b8230'},
#  'response': {'venues': [{'id': '5b897e92db1d81002c91df8c',
#     'name': 'Fabbrica Rustic Italian',
#     'location': {'address': '66 Wellington St W',
#      'lat': 43.647161,
#      'lng': -79.381691,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647161,
#        'lng': -79.381691}],
#      'distance': 346,
#      'postalCode': 'M5K 1E7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['66 Wellington St W',
#       'Toronto ON M5K 1E7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590499167',
#     'hasPerk': False},
#    {'id': '4f88cf84e4b002b90ab3b9b9',
#     'name': "LA's Italian + Bar",
#     'location': {'lat': 43.65053979517576,
#      'lng': -79.38460322737672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65053979517576,
#        'lng': -79.38460322737672}],
#      'distance': 216,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590499167',
#     'hasPerk': False},
#    {'id': '4c787c9181bca0936180fa14',
#     'name': 'Classic italian style pizza food truck',
#     'location': {'address': 'CNE Midway',
#      'lat': 43.652144,
#      'lng': -79.381118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652144,
#        'lng': -79.381118}],
#      'distance': 518,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['CNE Midway', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590499167',
#     'hasPerk': False},
#    {'id': '581cad6a7c74e15859a6f890',
#     'name': 'Scaddabush Italian Kitchen & Bar',
#     'location': {'address': '200 Front St W',
#      'crossStreet': 'at Simcoe St',
#      'lat': 43.6447367776608,
#      'lng': -79.38535477982775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6447367776608,
#        'lng': -79.38535477982775}],
#      'distance': 440,
#      'postalCode': 'M5V 3J1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Front St W (at Simcoe St)',
#       'Toronto ON M5V 3J1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590499167',
#     'hasPerk': False},
#    {'id': '4b3ace79f964a520ae6e25e3',
#     'name': 'Kit Kat Italian Bar & Grill',
#     'location': {'address': '297 King St W',
#      'crossStreet': 'at John St',
#      'lat': 43.64641598988062,
#      'lng': -79.39003009548966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64641598988062,
#        'lng': -79.39003009548966}],
#      'distance': 448,
#      'postalCode': 'M5V 1J5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['297 King St W (at John St)',
#       'Toronto ON M5V 1J5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590499167',
#     'hasPerk': False},
#    {'id': '4b7d777df964a52043c02fe3',
#     'name': 'Sauté Rosé',
#     'location': {'address': '55 University Ave.',
#      'crossStreet': 'in Markel Building',
#      'lat': 43.646547314182634,
#      'lng': -79.38402865696358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646547314182634,
#        'lng': -79.38402865696358}],
#      'distance': 264,
#      'postalCode': 'M5J 2H7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['55 University Ave. (in Markel Building)',
#       'Toronto ON M5J 2H7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590499167',
#     'hasPerk': False},
#    {'id': '4b846dd4f964a520dc3431e3',
#     'name': "Little Anthony's",
#     'location': {'address': '121 Richmond St. W',
#      'crossStreet': 'at York St.',
#      'lat': 43.65029624519052,
#      'lng': -79.38451301997945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65029624519052,
#        'lng': -79.38451301997945}],
#      'distance': 193,
#      'postalCode': 'M5H 2K1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['121 Richmond St. W (at York St.)',
#       'Toronto ON M5H 2K1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '75877692'},
#     'referralId': 'v-1590499167',
#     'hasPerk': False},
#    {'id': '4aa9328df964a5206b5220e3',
#     'name': "Joe Badali's Ristorante Italiano & Bar",
#     'location': {'address': '156 Front St W',
#      'crossStreet': 'at Simcoe St',
#      'lat': 43.645129694026686,
#      'lng': -79.3850249304319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645129694026686,
#        'lng': -79.3850249304319}],
#      'distance': 397,
#      'postalCode': 'M5J 2L6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['156 Front St W (at Simcoe St)',
#       'Toronto ON M5J 2L6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590499167',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
#
#                          id    location.address location.cc location.city  \
# 0  5b897e92db1d81002c91df8c  66 Wellington St W          CA       Toronto
# 1  4f88cf84e4b002b90ab3b9b9                 NaN          CA           NaN
# 2  4c787c9181bca0936180fa14          CNE Midway          CA       Toronto
# 3  581cad6a7c74e15859a6f890      200 Front St W          CA       Toronto
# 4  4b3ace79f964a520ae6e25e3       297 King St W          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                346
# 1           Canada                  NaN                216
# 2           Canada                  NaN                518
# 3           Canada         at Simcoe St                440
# 4           Canada           at John St                448
#
#                            location.formattedAddress  \
# 0   [66 Wellington St W, Toronto ON M5K 1E7, Canada]
# 1                                           [Canada]
# 2                   [CNE Midway, Toronto ON, Canada]
# 3  [200 Front St W (at Simcoe St), Toronto ON M5V...
# 4  [297 King St W (at John St), Toronto ON M5V 1J...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.647161, 'lng':...     43.647161
# 1  [{'label': 'display', 'lat': 43.65053979517576...     43.650540
# 2  [{'label': 'display', 'lat': 43.652144, 'lng':...     43.652144
# 3  [{'label': 'display', 'lat': 43.6447367776608,...     43.644737
# 4  [{'label': 'display', 'lat': 43.64641598988062...     43.646416
#
#    location.lng location.postalCode location.state  \
# 0    -79.381691             M5K 1E7             ON
# 1    -79.384603                 NaN            NaN
# 2    -79.381118                 NaN             ON
# 3    -79.385355             M5V 3J1             ON
# 4    -79.390030             M5V 1J5             ON
#
#                                      name    referralId venuePage.id
# 0                 Fabbrica Rustic Italian  v-1590499167          NaN
# 1                      LA's Italian + Bar  v-1590499167          NaN
# 2  Classic italian style pizza food truck  v-1590499167          NaN
# 3        Scaddabush Italian Kitchen & Bar  v-1590499167          NaN
# 4             Kit Kat Italian Bar & Grill  v-1590499167          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                      name          categories  \
# 0                 Fabbrica Rustic Italian  Italian Restaurant
# 1                      LA's Italian + Bar  Italian Restaurant
# 2  Classic italian style pizza food truck          Food Truck
# 3        Scaddabush Italian Kitchen & Bar  Italian Restaurant
# 4             Kit Kat Italian Bar & Grill  Italian Restaurant
# 5                              Sauté Rosé  Italian Restaurant
# 6                        Little Anthony's  Italian Restaurant
# 7  Joe Badali's Ristorante Italiano & Bar  Italian Restaurant
#
#               address  cc     city country         crossStreet  distance  \
# 0  66 Wellington St W  CA  Toronto  Canada                 NaN       346
# 1                 NaN  CA      NaN  Canada                 NaN       216
# 2          CNE Midway  CA  Toronto  Canada                 NaN       518
# 3      200 Front St W  CA  Toronto  Canada        at Simcoe St       440
# 4       297 King St W  CA  Toronto  Canada          at John St       448
# 5  55 University Ave.  CA  Toronto  Canada  in Markel Building       264
# 6  121 Richmond St. W  CA  Toronto  Canada         at York St.       193
# 7      156 Front St W  CA  Toronto  Canada        at Simcoe St       397
#
#                                     formattedAddress  \
# 0   [66 Wellington St W, Toronto ON M5K 1E7, Canada]
# 1                                           [Canada]
# 2                   [CNE Midway, Toronto ON, Canada]
# 3  [200 Front St W (at Simcoe St), Toronto ON M5V...
# 4  [297 King St W (at John St), Toronto ON M5V 1J...
# 5  [55 University Ave. (in Markel Building), Toro...
# 6  [121 Richmond St. W (at York St.), Toronto ON ...
# 7  [156 Front St W (at Simcoe St), Toronto ON M5J...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.647161, 'lng':...  43.647161 -79.381691
# 1  [{'label': 'display', 'lat': 43.65053979517576...  43.650540 -79.384603
# 2  [{'label': 'display', 'lat': 43.652144, 'lng':...  43.652144 -79.381118
# 3  [{'label': 'display', 'lat': 43.6447367776608,...  43.644737 -79.385355
# 4  [{'label': 'display', 'lat': 43.64641598988062...  43.646416 -79.390030
# 5  [{'label': 'display', 'lat': 43.64654731418263...  43.646547 -79.384029
# 6  [{'label': 'display', 'lat': 43.65029624519052...  43.650296 -79.384513
# 7  [{'label': 'display', 'lat': 43.64512969402668...  43.645130 -79.385025
#
#   postalCode state                        id
# 0    M5K 1E7    ON  5b897e92db1d81002c91df8c
# 1        NaN   NaN  4f88cf84e4b002b90ab3b9b9
# 2        NaN    ON  4c787c9181bca0936180fa14
# 3    M5V 3J1    ON  581cad6a7c74e15859a6f890
# 4    M5V 1J5    ON  4b3ace79f964a520ae6e25e3
# 5    M5J 2H7    ON  4b7d777df964a52043c02fe3
# 6    M5H 2K1    ON  4b846dd4f964a520dc3431e3
# 7    M5J 2L6    ON  4aa9328df964a5206b5220e3

# %%
dataframe_filtered.name
# Out:
# 0                   Fabbrica Rustic Italian
# 1                        LA's Italian + Bar
# 2    Classic italian style pizza food truck
# 3          Scaddabush Italian Kitchen & Bar
# 4               Kit Kat Italian Bar & Grill
# 5                                Sauté Rosé
# 6                          Little Anthony's
# 7    Joe Badali's Ristorante Italiano & Bar
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-84dd12227b0f> in <module>
#       2
#       3 # add a red circle marker to represent the Conrad Hotel
# ----> 4 folium.features.CircleMarker(
#       5     [latitude, longitude],
#       6     radius=10,
#
# AttributeError: module 'folium.features' has no attribute 'CircleMarker'
